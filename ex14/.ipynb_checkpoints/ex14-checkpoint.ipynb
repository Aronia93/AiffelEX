# %% [markdown]
# ## 루브릭
#
# 1. pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.
# 데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.
# 2. pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.
# U-Net generator, discriminator 모델 구현이 완료되어 train_step의 output을 확인하고 개선하였다.
# 3. 학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.
# 10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.

# %% [markdown]
# ### 데이터 불러오기

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2

# %%
import os
data_path = os.getenv('HOME')+'/aiffel/workplace/AiffelEX/ex14/cityscapes/train/'
data_path_v = os.getenv('HOME')+'/aiffel/workplace/AiffelEX/ex14/cityscapes/val/'
print("number of train :", len(os.listdir(data_path_t)))
print("number of val :", len(os.listdir(data_path_v)))
# Out:
# number of train : 1000
# number of val : 5

# %%
plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(1000)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)
plt.show()

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %% [markdown]
# ### 이미지 분할하기

# %% [markdown]
# ### 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요. (어떠한 방법을 사용했는지 적어주세요.)
#
# - 기존 노드에서 사용한, 무작위로 뒤집고, 회전시키는 방법 사용

# %%
import tensorflow as tf

def normalize(x): # 정규화
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):  # 이미지 분할
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, w:, :]
    sketch = tf.cast(sketch, tf.float32)  # 위의 오른쪽을 스케치로(RGB)
    colored = img[:, :w, :] 
    colored = tf.cast(colored, tf.float32) # 위의 왼쪽은 컬러로 (원본)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1) # 이미지의 채널축 연결
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:    
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])  #이미지 잘라내기
    
    out = image.random_flip_left_right(out) # 이미지 가로 뒤집기
    out = image.random_flip_up_down(out) # 이미지 세로로 뒤집기
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree) # 이미지 회전시키기
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ### 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.

# %%
from tensorflow.keras import layers, Input, Model


class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

UNetGenerator().get_summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_13 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_224 (EncodeBlock)  (None, 128, 128, 64) 3072        input_13[0][0]
# __________________________________________________________________________________________________
# encode_block_225 (EncodeBlock)  (None, 64, 64, 128)  131584      encode_block_224[0][0]
# __________________________________________________________________________________________________
# encode_block_226 (EncodeBlock)  (None, 32, 32, 256)  525312      encode_block_225[0][0]
# __________________________________________________________________________________________________
# ...

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else layers.Activation('sigmoid') 
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        filters = [64,128,256,512,1]
        self.blocks = [layers.Concatenate()]
        # For문을 활용해서 DiscBlock을 쌓아주세요.
        # 조건 1 : 3번째까지 stride는 2로 주되 이후에는 1로 주세요
        # 조건 2 : 3번째까지 custom padding을 주지 않아도 되는데 이후에는 주세요.
        # 조건 3: 1번째와 5번째에서는 Batch Normalization을 사용하지 마세요.
        # 조건 4 : 1번째부터 4번째까지 LeakyReLU를 적용하고 마지막에는 sigmoid를 적용하세요. (sigmoid의 경우 따로 정의해야 합니다)
        for i in range(len(filters) - 1):
            n_filters = filters[i]
            stride = 2 if i < 3 else 1
            custom_pad = i >= 3
            use_bn = i > 0 and i < 4
            act = i < 4
            disc_block = DiscBlock(n_filters, stride, custom_pad, use_bn, act)
            self.blocks.append(disc_block)
        self.sigmoid = DiscBlock(n_filters=1, stride=1, 
                                 custom_pad=True, use_bn=False, act=False)
        # act=False 이면 시그모이드 적용 (DiscBlock에서 재정의)

    def call(self, x, y):
        out = self.blocks[0]([x, y])
        for i in range(1, len(self.blocks)):
            out = self.blocks[i](out)

        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
Discriminator().get_summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_14 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_154 (Concatenate)   (None, 256, 256, 6)  0           input_14[0][0]
#                                                                  input_15[0][0]
# __________________________________________________________________________________________________
# disc_block_140 (DiscBlock)      (None, 128, 128, 64) 6144        concatenate_154[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ### 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
#
# ### 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
generator = UNetGenerator()
discriminator = Discriminator()


@tf.function
def train_step(sketch, colored):      
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
    # 이전에 배웠던 내용을 토대로 train_step을 구성해주세요.
        fake_output = generator(sketch)
        # Discriminator를 이용해 진짜 및 가짜이미지를 각각 판별
        real_disc = discriminator(sketch, colored)
        fake_disc = discriminator(sketch, fake_output)
            
        # 각 손실(loss)을 계산
        gene_loss, l1_loss = get_gene_loss(fake_output, colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        disc_loss = get_disc_loss(fake_disc, real_disc) 
      
    # gradient 계산    
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    # 모델 학습    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 5

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images): # colored : 실제 이미지
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 50회 반복마다 손실을 출력합니다.
        if (i+1) % 50 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[50]
# Generator_loss:0.6843
# L1_loss:0.2700
# Discriminator_loss:1.4902
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.4023
# L1_loss:0.2672
# Discriminator_loss:1.3900
#
# EPOCH[1] - STEP[150]
# Generator_loss:0.8194
# L1_loss:0.2063
# Discriminator_loss:1.0353
#
# EPOCH[1] - STEP[200]
# Generator_loss:0.8034
# L1_loss:0.1991
# Discriminator_loss:1.1272
#
# EPOCH[1] - STEP[250]
# Generator_loss:13.0692
# L1_loss:0.1796
# Discriminator_loss:12.8498
#
# EPOCH[2] - STEP[50]
# Generator_loss:0.8598
# L1_loss:0.1763
# Discriminator_loss:1.1040
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.0141
# L1_loss:0.1614
# Discriminator_loss:0.9738
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.8009
# L1_loss:0.1664
# Discriminator_loss:1.7076
#
# EPOCH[2] - STEP[200]
# Generator_loss:0.8662
# L1_loss:0.1686
# Discriminator_loss:1.0980
#
# EPOCH[2] - STEP[250]
# Generator_loss:1.1260
# L1_loss:0.1902
# Discriminator_loss:1.0671
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.1391
# ...

# %%
test_ind = 1

f_v = data_path_v + os.listdir(data_path_v)[test_ind]
sketch, colored = load_img(f_v)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch)) # RGB 스타일
plt.title("input_image")
plt.subplot(1,3,2); plt.imshow(denormalize(colored)) # 원본 스타일
plt.title("colored_image")
plt.subplot(1,3,3); plt.imshow(pred[0])
plt.title("output_image")
# Out:
# Text(0.5, 1.0, 'output_image')

# %% [markdown]
# ### 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %%
generator = UNetGenerator()
discriminator = Discriminator()


@tf.function
def train_step2x(sketch, colored):      
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
    # 이전에 배웠던 내용을 토대로 train_step을 구성해주세요.
        fake_output = generator(sketch)
        # Discriminator를 이용해 진짜 및 가짜이미지를 각각 판별
        real_disc = discriminator(sketch, colored)
        fake_disc = discriminator(sketch, fake_output)
            
        # 각 손실(loss)을 계산
        gene_loss, l1_loss = get_gene_loss(fake_output, colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        disc_loss = get_disc_loss(fake_disc, real_disc) 
      
    # gradient 계산    
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    # 모델 학습    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images): # colored : 실제 이미지
        g_loss, l1_loss, d_loss = train_step2x(sketch, colored)
                
        # 50회 반복마다 손실을 출력합니다.
        if (i+1) % 50 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[50]
# Generator_loss:-0.0000
# L1_loss:0.2530
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[100]
# Generator_loss:-0.0000
# L1_loss:0.2186
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[150]
# Generator_loss:-0.0000
# L1_loss:0.2213
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[200]
# Generator_loss:-0.0000
# L1_loss:0.1566
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[250]
# Generator_loss:-0.0000
# L1_loss:0.2118
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[50]
# Generator_loss:-0.0000
# L1_loss:0.1970
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[100]
# Generator_loss:-0.0000
# L1_loss:0.2092
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[150]
# Generator_loss:-0.0000
# L1_loss:0.1686
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[200]
# Generator_loss:-0.0000
# L1_loss:0.1606
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[250]
# Generator_loss:-0.0000
# L1_loss:0.1669
# Discriminator_loss:15.2492
#
# EPOCH[3] - STEP[50]
# ...

# %%
test_ind = 1

f_v = data_path_v + os.listdir(data_path_v)[test_ind]
sketch, colored = load_img(f_v)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.title("input_image")
plt.subplot(1,3,2); plt.imshow(denormalize(colored))
plt.title("colored_image")
plt.subplot(1,3,3); plt.imshow(pred[0])
plt.title("output_image")
# Out:
# Text(0.5, 1.0, 'output_image')

# %%
generator = UNetGenerator()
discriminator = Discriminator()


@tf.function
def train_step3x(sketch, colored):      
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
    # 이전에 배웠던 내용을 토대로 train_step을 구성해주세요.
        fake_output = generator(sketch)
        # Discriminator를 이용해 진짜 및 가짜이미지를 각각 판별
        real_disc = discriminator(sketch, colored)
        fake_disc = discriminator(sketch, fake_output)
            
        # 각 손실(loss)을 계산
        gene_loss, l1_loss = get_gene_loss(fake_output, colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        disc_loss = get_disc_loss(fake_disc, real_disc) 
      
    # gradient 계산    
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    # 모델 학습    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 15

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images): # colored : 실제 이미지
        g_loss, l1_loss, d_loss = train_step3x(sketch, colored)
                
        # 50회 반복마다 손실을 출력합니다.
        if (i+1) % 50 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[50]
# Generator_loss:-0.0000
# L1_loss:0.2755
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[100]
# Generator_loss:-0.0000
# L1_loss:0.2069
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[150]
# Generator_loss:-0.0000
# L1_loss:0.2270
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[200]
# Generator_loss:-0.0000
# L1_loss:0.2046
# Discriminator_loss:15.2492
#
# EPOCH[1] - STEP[250]
# Generator_loss:-0.0000
# L1_loss:0.2227
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[50]
# Generator_loss:-0.0000
# L1_loss:0.1929
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[100]
# Generator_loss:-0.0000
# L1_loss:0.2008
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[150]
# Generator_loss:-0.0000
# L1_loss:0.2283
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[200]
# Generator_loss:-0.0000
# L1_loss:0.2325
# Discriminator_loss:15.2492
#
# EPOCH[2] - STEP[250]
# Generator_loss:-0.0000
# L1_loss:0.2331
# Discriminator_loss:15.2492
#
# EPOCH[3] - STEP[50]
# ...

# %%
test_ind = 1

f_v = data_path_v + os.listdir(data_path_v)[test_ind]
sketch, colored = load_img(f_v)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.title("input_image")
plt.subplot(1,3,2); plt.imshow(denormalize(colored))
plt.title("colored_image")
plt.subplot(1,3,3); plt.imshow(pred[0])
plt.title("output_image")
# Out:
# Text(0.5, 1.0, 'output_image')

# %% [markdown]
# ### 에포크별 결과 비교
#
# - 5 에포크 학습 결과물
# ![image.png](attachment:image.png)
#
# - 10 에포크 학습 결과물
# ![image-2.png](attachment:image-2.png)
#
# - 15 에포크 학습 결과물
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 에포크 수를 늘려감에 따라 이미지 재현도가 좋아짐을 알 수 있다.
